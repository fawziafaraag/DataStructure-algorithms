# %% [markdown]
# <a href="https://colab.research.google.com/github/fawziafaraag/Data_structure-algorithm_lab-2/blob/main/datastructure%26AlgorithmsLab_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## inorder
## left,Root,Right

class Node:
    def __init__(self, key):
        self.left = None
        self.right = None
        self.val = key
 
 
# A function to do inorder tree traversal
def printInorder(root):
 
    if root:
 
        # First recur on left child
        printInorder(root.left)
 
        # then print the data of node
        print(root.val),
 
        # now recur on right child
        printInorder(root.right)
 
 
# Driver code
if __name__ == "__main__":
    root = Node(1)
    root.left = Node(2)
    root.left.left = Node(4)
    root.left.left.left = Node(7)
    root.left.right = Node(5)
    root.left.right.left = Node(8)
    root.right = Node(3)
    root.right.right = Node(6)
    root.right.right.left = Node(9)
    root.right.right.left.left = Node(11)
    root.right.right.right = Node(10)
    root.right.right.right.left  = Node(12)
 
    # Function call
    print ("\nInorder traversal of binary tree is")
    printInorder(root)
# Out:
# Inorder traversal of binary tree is
# 7
# 4
# 2
# 8
# 5
# 1
# 3
# 11
# 9
# 6
# 12
# 10

# %%
##Preorder
##Root,left,right
class Node:
    def __init__(self, key):
        self.left = None
        self.right = None
        self.val = key
 
 
# A function to do preorder tree traversal
def printPreorder(root):
 
    if root:
 
        # First print the data of node
        print(root.val),
 
        # Then recur on left child
        printPreorder(root.left)
 
        # Finally recur on right child
        printPreorder(root.right)
 
 
# Driver code
if __name__ == "__main__":
    root = Node(1)
    root.left = Node(2)
    root.left.left = Node(4)
    root.left.left.left = Node(7)
    root.left.right = Node(5)
    root.left.right.left = Node(8)
    root.right = Node(3)
    root.right.right = Node(6)
    root.right.right.left = Node(9)
    root.right.right.left.left = Node(11)
    root.right.right.right = Node(10)
    root.right.right.right.left  = Node(12)
 
  # Function call
    print ("Preorder traversal of binary tree is")
    printPreorder(root)
# Out:
# Preorder traversal of binary tree is
# 1
# 2
# 4
# 7
# 5
# 8
# 3
# 6
# 9
# 11
# 10
# 12

# %%
##Postorder
##left,right,root
class Node:
    def __init__(self, key):
        self.left = None
        self.right = None
        self.val = key
 
# A function to do postorder tree traversal
def printPostorder(root):
 
    if root:
 
        # First recur on left child
        printPostorder(root.left)
 
        # the recur on right child
        printPostorder(root.right)
 
        # now print the data of node
        print(root.val),
 
 
# Driver code
if __name__ == "__main__":
    root = Node(1)
    root.left = Node(2)
    root.left.left = Node(4)
    root.left.left.left = Node(7)
    root.left.right = Node(5)
    root.left.right.left = Node(8)
    root.right = Node(3)
    root.right.right = Node(6)
    root.right.right.left = Node(9)
    root.right.right.left.left = Node(11)
    root.right.right.right = Node(10)
    root.right.right.right.left  = Node(12)
 
  # Function call
    print ("\nPostorder traversal of binary tree is")
    printPostorder(root)
# Out:
# Postorder traversal of binary tree is
# 7
# 4
# 8
# 5
# 2
# 11
# 9
# 12
# 10
# 6
# 3
# 1

# %% [markdown]
# # Task#2
#
#
# ![Task#2.PNG](data:image/png;base64,...)
